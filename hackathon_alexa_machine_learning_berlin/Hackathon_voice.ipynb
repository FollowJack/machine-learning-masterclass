# %% [markdown]
# # Hackathon - Machine Learning Hackathon with Goethe-Institut
# https://www.eventbrite.de/e/machine-learning-hackathon-with-goethe-institut-tickets-54654465979?aff=ebdssbdestsearch

# %% [markdown]
# # Team Dublingo
# Movie karaoke - Dub movie files
#
# Wonderful party game idea. Really good as insentive for data collection.
#
# Machine Learning: XXX
# Technical Goal: Vowel scoring.
#
# Credits to:
# - https://github.com/libphy/which_animal/blob/master/code/createdata.py

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# library for audio and music analysis 
# https://github.com/librosa/librosa 
# used for MFCC: see https://en.wikipedia.org/wiki/Mel-frequency_cepstrum
import librosa
import librosa.display

# %%
# files 
path = 'data/'
waveFiles = ['oooo.wav', 'öoou.wav']

# %%
for file in waveFiles: 
    # y : np.ndarray [shape=(n,) or (2, n)]
    # sampling rate of y
    y, sampling_rate = librosa.load(path+file)
    
    # https://librosa.github.io/librosa/generated/librosa.feature.mfcc.html
    mfcc = librosa.feature.mfcc(y=y, sr=sampling_rate, n_mfcc=13)
    # M : np.ndarray [shape=(n_mfcc, t)] MFCC sequence
    
    plt.figure(figsize=(10, 4))
    
    axes_subplot = librosa.display.specshow(mfcc, x_axis='time')
    plt.colorbar(label='Frequency Density')
    #plt.clabel = 'aa'
    plt.title(file)
    plt.tight_layout()
    print(bla)
# Out:
# AxesSubplot(0.0198611,0.145139;0.960278x0.761806)
# AxesSubplot(0.0198611,0.145139;0.960278x0.761806)
