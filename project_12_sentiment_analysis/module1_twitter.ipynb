# %%
import tweepy
from textblob import TextBlob

# %%
# Step 1 - Authenticate
consumer_key= 'Z3dK7LmOsfjxY0wUDRrhzhtuf'
consumer_secret= 'pCSoTeyTV9vqocSAPC4YroFGguWbYC994G68DSpFpivb4kzQBG'

access_token='917532542949085189-WmnK90WIkLVblHTavb1oS70rFvckZd7'
access_token_secret='nqqMIGpS3n6p0Grf34PxZqmi331Ngfl6I4NKexWx9Fcs9'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
#Step 3 - Retrieve Tweets
public_tweets = api.search('Bad')

#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself


for tweet in public_tweets:
    print(tweet.text)
    print('Analysis')
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    if analysis.sentiment.polarity >= 0.2:
        print('Positiv')
    elif analysis.sentiment.polarity <= -0.2:
        print('Negativ')
    else:
        print('Neutral')
    print("")
# Out:
# Att få ett upplevelse-presentkort är att få en omöjlig arbetsuppgift. https://t.co/CWuoVdF9zN
# Analysis
# Neutral
#
# RT @_ftjanina: Unfollowed primadonnas who bad mouthed jonghun. Even if he did those things ofcourse I am still offended when I read those c…
# Analysis
# Negativ
#
# silver boys: yg vibes, hip hop, swag, bad bitches
#
# treasure: teletubbies https://t.co/XK01htRUBa
# Analysis
# Negativ
#
# I’m bad at both tho https://t.co/WDc811bonP
# Analysis
# Negativ
#
# RT @purpleVerryTae: Other idols *trending for a bad scandal*
#
# Kim Taehyung *trending for a selca being shirtless and beautiful*
# Analysis
# Neutral
#
# RT @jennagazem: Im so bad for bottling everything up n then going off my nut at the tiniest thing n everyone thinks am being a psycho cause…
# Analysis
# Negativ
#
# the world is so bad sometimes I forget how bad it is
# Analysis
# Negativ
#
# @x2STRK2x パッドで出せたらさすがとしか言えないっすわ
# Analysis
# Neutral
#
# RT @myfashlan: How bad is pasir gudang?
#
# Private clinic closed
# Hospitals are no longer accepting new patients
# Workers took their family aw…
# Analysis
# Neutral
#
# @Radioacktiva_ @ElPenultimoTV @IronMaiden @gacelacardona @juankiss67 #MiPrimerDisco fue BAD de Michael Jackson, est… https://t.co/3o5ch8tzRV
# Analysis
# Negativ
#
# These are the lefty Jewish kids who think sticking fingers in light sockets has gotten a bad rap. https://t.co/Naq0CU51o7
# Analysis
# Neutral
#
# @ANGRYFAN0071 Battle rap can be like boxing sometimes...you got Roc Kshine Geechi their like the welterweights..the… https://t.co/0SZA3Y9wLO
# Analysis
# Neutral
#
# @ChefStuart_ Happy Pie Day! Sorry. Cancel that. It’s Pi (mathematical constant) Day. My bad! Do you suddenly have a craving for 🥧?!!! 😂
# Analysis
# Neutral
#
# RT @Slate: Millions of ordinary workers will be unable to qualify for overtime because of this new Trump rule. https://t.co/g8cS5kEnzi
# Analysis
# Negativ
#
# RT @ImPaki1: Femenist will stay quiet about this war hero and will continue to praise Ariana Grande cause she portrays bad bitch behavior.…
# Analysis
# Negativ

# %% [markdown]
# # Playfield for Twitter Client

# %%
'''
Generic Twitter Client
'''
class TwitterClient:
    def __init__(self):
        consumer_key= 'Z3dK7LmOsfjxY0wUDRrhzhtuf'
        consumer_secret= 'pCSoTeyTV9vqocSAPC4YroFGguWbYC994G68DSpFpivb4kzQBG'
        access_token='917532542949085189-WmnK90WIkLVblHTavb1oS70rFvckZd7'
        access_token_secret='nqqMIGpS3n6p0Grf34PxZqmi331Ngfl6I4NKexWx9Fcs9'
   
        self.auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        self.auth.set_access_token(access_token, access_token_secret)
        self.api = tweepy.API(self.auth)
        self.tweet_n_max = 100
        
    def get_tweets(self, query):
        tweets = []
        raw_tweets = self.api.search(q=query, count=self.tweet_n_max)

        for tweet in raw_tweets:
            parsed_tweet = {}
            parsed_tweet['text'] = tweet.text
            parsed_tweet['user'] = tweet.user.screen_name
            sentiment = self.get_sentiment(tweet.text)
            parsed_tweet['sentiment_status'] = sentiment[0]
            parsed_tweet['sentiment_polarity'] = sentiment[1]
            
            tweets.append(parsed_tweet)
        
        return tweets
    
    def get_sentiment(self, tweet_text):
        analysis = TextBlob(tweet_text)
        if analysis.sentiment.polarity > 0:
            return ('positive',analysis.sentiment.polarity)
        elif analysis.sentiment.polarity < 0:
            return ('negative',analysis.sentiment.polarity)
        return ('neutral',analysis.sentiment.polarity)

client = TwitterClient()
client

# %%
client.get_tweets('happy')
# Out:
# [{'text': 'Happy bday mas!!❤️ u!!!! @masonmack21 https://t.co/sTqPpMnPB5',
#   'user': 'elliigracee',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'If I could get some Steers right now, I will be happy 😭',
#   'user': '_diimpho_',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5428571428571429},
#  {'text': 'Happy Birthday! She’s a real beauty! https://t.co/Y5vdTEhdB7',
#   'user': 'severngrl',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.625},
#  {'text': 'RT @BobOngHugots: Pretending to be happy is just an example of how strong person you are.',
#   'user': 'Jhnth23',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.6166666666666667},
#  {'text': 'RT @MMmmbread: Thelmas new hat. Oldest steam punker in coalville. Happy birthday for yesterday 80 years young. Celebrating with glass of bu…',
#   'user': 'CoalvilleMarket',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.34545454545454546},
#  {'text': 'RT @ARIFURETA_info: 【Happy💙Whiteday】\n本日はホワイトデーですね！\nみなさん、ちゃんと準備はできていますか？\n\nもちろん、ユエからもらったんですから\nお返しは用意してますよね🤔？\n\nぜひ、たくさんの愛をユエやヒロインたちにあげてください\U0001f970🎊\nで…',
#   'user': 'tsubame012',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @Henry_Cheal: There’s only one Jim Bowen.\n\nOne year on, I still think of you.\n\nThe memories watching your show \ngrowing up is making me…',
#   'user': 'Assonrichard',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': '@wnmiyu ありがとうございます😊\nホッとしました‼️',
#   'user': 'happy_smile0213',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'Seeing Bom performing on stage today. I feel so proud and so happy for her. The last time she was on stage was at M… https://t.co/pYFQdHqc3c',
#   'user': 'lune_et_ciel',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5333333333333333},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': 'wldmsql1963',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @almdm_: happy birthday, @MarcoBacanaya!!! \U0001f973🎂🎈',
#   'user': 'MarcoBacanaya',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @iam_juhi: Aammmiirrrrr ..!!! Happy Happy Happy Birthday ...!!!!! Have a super duper day and make another fabulous film this year ...!!!…',
#   'user': 'AgamAnEntity',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.6666666666666667},
#  {'text': 'RT @BT21_: Cutie-pie 😋\n#Happy #PiDay \n#NeverEnding #Stories of #BT21 https://t.co/AI3SEWofAZ',
#   'user': 'Hobie_0218',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @neiltyson: March 14th. (3.14)\n\nHappy Pi day to pi-maniacs out there.',
#   'user': 'gaymergyrl',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @jacksseunn: happy 1st year anniversary of jackson’s ice cream sad story https://t.co/fCkKveQuPr',
#   'user': 'Notjustbtstras1',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.15000000000000002},
#  {'text': '@UofLPresNeeli Happy \U0001f967 day @antha79',
#   'user': 'MilesFitz',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @Cmdr_Hadfield: The crew is happy as ... https://t.co/aHVd4JYeyI',
#   'user': 'JoanCostello1',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': "It's hilarious that Pakis are celebrating #China blocking ban on #MasoodAzhar at UN. It's nothing but a rich bloke… https://t.co/LqFM2YEHWK",
#   'user': 'DisDatNothin',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4375},
#  {'text': 'RT @PnPCBC: .@theJagmeetSingh outlined what his party wants to see in the federal budget and said he’d be happy if the Liberals crossed eve…',
#   'user': '_rileypeterson',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5},
#  {'text': '@ChadMichaels1 Just mentioned on The Bob &amp; Tom show for Cher impersonation. So happy to hear the nationwide recognition. Yay!',
#   'user': 'SheTiger68',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @PatrickSvitek: Just in: It\'s official.\n\n@BetoORourke: "Amy and I are happy to share with you that I\'m running to serve you as the next…',
#   'user': 'woodnrye',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @fermatslibrary: Happy π day!\n\nπ=3️⃣,1⃣4️⃣1592653589793238462643383279502884197169399375105820974944592307816406286208998628034825342117…',
#   'user': 'Fkawauso',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': "Today is your birthday and I don't even have anything to say to you.  But no forget say you be my guy well well.\n\nH… https://t.co/YxW0cSao50",
#   'user': 'TurakinArewa',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @hr130130: A dream is only a dream until you take action. Make it happen! 💐💐 #happy #saterd... (Vine by @worldloveflower) https://t.co/v…',
#   'user': 'Alde0701',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.30833333333333335},
#  {'text': 'HAPPY WHITEDAY!\n\n歌仙『いつもありがとう』\n山姥切『これからもよろしく頼む』\n薬研『愛してるぜ、大将！』\n\nというわけで、我が本丸の刀剣男士を代表して3振からバレンタインのお返しを頂きました！\nありがとうね！\nみん… https://t.co/ir1zrtrvpa',
#   'user': 'Fivestarwhale',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @_youhadonejob1: Happy Pi Day. #PiDay2019 https://t.co/V7PHLCWRUv',
#   'user': 'JoannHillnyc',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'Chris makes me so happy \U0001f929',
#   'user': 'breanap14',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'Happy to see Travis back! Prove the haters  and losers wrong TdA!  #LGM #Mets https://t.co/QyOD8JZyWq',
#   'user': 'NYMetsChief',
#   'sentiment_status': 'negative',
#   'sentiment_polarity': -0.006249999999999978},
#  {'text': 'RT @9795ofmoonlight: [TRANS] 14/03/19 \nV - LIVE KWON HYUNBIN \nHAPPY WHITE DAY\n\nQ. : ยังติดต่อกับมินฮยอนโอป้าอยู่มั้ยคะ?\nฮยอนบิน : ครับ กับ…',
#   'user': 'pknjob',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.0465909090909091},
#  {'text': "RT @25Anchor: @amemiya_dp \n\nあのね(✌🏻️'ω'✌🏻️)\n最近さぁー\nちょwwwスーパーハイテンション\nになってきてるよ！\n色んな事に対して\n頑張れたりする力や 自分と向き合い好きになれたよ♡´･ᴗ･`♡\n\nだから\n沢山の仲間\n仲良く出来てるかもしれ…",
#   'user': '25Anchor',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @dailykrumbs: Good morning ♥\n#kacchako #勝茶 \n\nreference https://t.co/jSSC4FG4wY https://t.co/pXveADrqGK',
#   'user': 'bamexplode',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.85},
#  {'text': 'Happy weekend amigos ❤️',
#   'user': 'i_HeMo2',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @bernice_bs16: @khadijatan HAAAAIII ATEEE!! happyy happy birthdayy hehe enjoy your day! Gbua💛',
#   'user': 'khadijatan',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.65},
#  {'text': 'RT @argturuinmd: 20190314\nhappy white day https://t.co/6oPIamBnXg',
#   'user': 'Saki12_5',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'We are happy to record the awarding of an Oxford Blue to Old Lawrentian, Ben Spencer, in boxing. On Saturday 9 Marc… https://t.co/T1hryNBz84',
#   'user': 'slcMain',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.3},
#  {'text': 'RT @rjcmxrell: i miss how happy i used to be',
#   'user': 'kkatedsz',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': "Finally!!! I'm so happy for you!!❤❤@kyoquijano https://t.co/bbsfSNdNm4",
#   'user': '_angelicaroxas',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @iqo_says: Happy birthday 🎂🎉🎊\nStay happy ❤️🎈🎈\n@RKisbEst',
#   'user': 'coco_moo_girlll',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@realDonaldTrump Proposing 15% budget cuts effecting subsidies and crop insurance. Farm Bureau leaders aren’t happy… https://t.co/fehZ07IsVF',
#   'user': 'Oldgadawg',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @BecksHybrids: Happy National Ag Day! Help us honor all those individuals that feed the world today and every day! \n\nFrom our farm to yo…',
#   'user': 'JacobTintes',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @SikyuCebu: IF you’re happy and you know it, would you clap your hands? — i would hold your hands https://t.co/TQoE6DwtkK',
#   'user': 'ShyrahGonzaga',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @HowardManns: 4yo\'s decided "as a pancake" is an adverb of degree. So:\n"Flat as a pancake" = very flat\n"Cool as a pancake" = very cool\n"…',
#   'user': 'SiTrill',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.18687499999999999},
#  {'text': 'RT @motorway0214: happy white day🎩\n\n#NCT127 #재현 #JAEHYUN https://t.co/OHBz3PxBYV',
#   'user': 'Taemina94',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @realDonaldTrump: Happy National Ag Day! https://t.co/hNkOh0TqvW',
#   'user': 'lsferguson',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'めっっちゃくちゃ忙しかった、\nプレートの文字喜んでくれて\n嬉しい〜疲れ吹っ飛び〜\nhappy White day!🍰🍪',
#   'user': 'mika_onigiri',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @mkraju: Just asked Nancy Pelosi about Manafort sentencing and if Trump should take off the table a pardon for Manafort, and she said: “…',
#   'user': 'HiAltDawg',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'gomaxio84',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': 'markprisun',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @mngxyu: (update chara) 🌟2019 HAPPY MINGYU DAY🌟\n\n➖\n\n민규야 생일 축하해 ♡\n\n사랑하는 민규의 생일을 맞아 많은 분들과 함께 축하하기 위해 컵홀더 이벤트를 준비했습니다.\n\n자세한 내용은 아래의 이미지를 참…',
#   'user': 'MINGYU_birthday',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.025000000000000022},
#  {'text': 'RT @realDonaldTrump: Happy National Ag Day! https://t.co/hNkOh0TqvW',
#   'user': 'MarkTho70412994',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'So  happy',
#   'user': 'hmrbmhk',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@presentcorrect Happy π everyone!',
#   'user': 'vileteen',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @MazeDaMouth: Critical thinking is a foreign language to some people. I was not, in that instance, defending the legitimacy of “men are…',
#   'user': 'PinkRubbiez',
#   'sentiment_status': 'negative',
#   'sentiment_polarity': -0.0625},
#  {'text': 'RT @Swamy39: I am happy that finally BJP media campaign has is now getting focused on Corruption of Congi leaders TDK Buddhu Bottle Goon Pu…',
#   'user': 'ranganaathan',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @WE_THE_BOYZ: [에릭] 해피 화이트 데이 💝\n           Happy White Day 🍭 https://t.co/e0HmSYFSJy',
#   'user': 'gooreum_V',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.01666666666666668},
#  {'text': 'RT @MollyJongFast: This makes me so happy.  https://t.co/Nc4EzfHHZu',
#   'user': 'TheLegitRebecca',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @mankai_stage: 💐✨🎀✨Happy WhiteDay✨🎀✨💐\n\n本日3月14日は💙🍭🍪ホワイトデー🍪🍭💙エーステカンパニーから監督さんへありがとうの気持ちをたくさん込めてお返しをお届けします❣\u3000\n\n#エーステ #ホワイトデー https://t.co/3v5…',
#   'user': 'maaaaatanz',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'Happy #NationalPiDay from the original pi... 😉 @The1stBAT @mrjafri @ronniehowlett3 @Tommymatts https://t.co/DnkM5LYyoa',
#   'user': 'thejonnyharris',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5875},
#  {'text': "RT @ABSCBN: @MW4LYF And when you see them happy, you're even more happier than them. \n\nAnd this is why #MayWard is perfect for each other.…",
#   'user': 'beayhen',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.7666666666666666},
#  {'text': 'RT @matthewjdowd: Happy Thursday to each of you.  Esther: \n“turn our mourning into gladness\nand our sorrows into wholeness."\n\nMay your sadn…',
#   'user': 'sallyagale',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@ChefStuart_ Happy Pie Day! Sorry. Cancel that. It’s Pi (mathematical constant) Day. My bad! Do you suddenly have a craving for \U0001f967?!!! 😂',
#   'user': 'Lisa_Campbell8',
#   'sentiment_status': 'negative',
#   'sentiment_polarity': -0.062499999999999965},
#  {'text': 'RT @Namo1154: I love you more than words can describe \n\nHappy Thai Elephant Day \n #วันช้างไทย https://t.co/pgGybOQww2',
#   'user': 'ploy_halety',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.6},
#  {'text': 'RT @Snowtale_326: ❄\n-\n2019 HAPPY XIUDAY PROJECT\n\nDonation + Xiumin bus\n\n[버스 운행노선,\xa0탑승 이벤트는\xa0추후 업데이트되며 기부증서는 생일날 업데이트됩니다]\n#봄을닮아_따스하고_다정한_시우민을_…',
#   'user': 'harri_0000',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'Happy Pi Day!! Baking to celebrate? Remember, every time you open the oven door, it lowers the temp by 25 degrees.… https://t.co/Me4gJV71Zx',
#   'user': 'cobbemc',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5},
#  {'text': 'RT @statman95: Happy Pi Day https://t.co/y8SwzY2XXH',
#   'user': 'sharpietweets',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @hariharannaidu: Happy for the trade talks. @iamharishkalyan bro. https://t.co/YH78FFipe3',
#   'user': 'kesavanrajendra',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@SashaGrey Happy Birthday! We hope you have an amazing day!',
#   'user': 'FamousBirthdays',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.875},
#  {'text': 'RT @BT21_: Cutie-pie 😋\n#Happy #PiDay \n#NeverEnding #Stories of #BT21 https://t.co/AI3SEWofAZ',
#   'user': 'lllLissaVlll',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @JackJ: Happy birthday @CaseyLowryMusic love ya u legend 🤙🏼',
#   'user': 'jackurreasm',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.65},
#  {'text': "RT @MisterHugotero: Fuck everything that doesn't make you happy.",
#   'user': 'HeinzTomatooo',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.2},
#  {'text': 'RT @aobuta_anime: ✨🎉Happy Birthday🎉✨\n\n本日3月14日はホワイトデー！\nというだけではなく…\n\n豊浜のどかの誕生日です！！\n\nこれからもぜひ、のどかと青ブタの応援をよろしくお願いいたします！\n\nのどかがジャケットイラストを飾るBD&amp;DVD第4…',
#   'user': 'Artvria',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'Happy Pi Day #PiDay2019 #PiDay https://t.co/ahL244CF3A',
#   'user': 'TWizardLibrary',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @therampagefext: 🌸🌸🌸\n\nHappy  White Day!!✨\n\n今日はホワイトデー☺️👏✨\n\n日頃から支えて頂いている皆さんへ、僕からの気持ちをお返しです🙏✨\n\n皆さまにとって素敵な一日になりますように🙏✨\n\nLove❤︎\n\n川村壱馬\n\n#THERA…',
#   'user': 'tomo_ex_AOS',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'You know what, i will no longer talk about that topic\nfelix baby youre so precious, you do you! You look good in an… https://t.co/Xr1vQkszGO',
#   'user': 'reybahng',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.6625},
#  {'text': 'RT @eyehinakhan: The depth and calmness of the sky personified in a genuine human being who’s greatness transforms everyone around him.\nI t…',
#   'user': 'sassyslytherinx',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.2},
#  {'text': 'RT @princejeongwoo: treasure makers aren’t jobless anymore. Treasure13 breathed. BUT u know what’s even better than that, we get our first…',
#   'user': 'Velvetxoxols',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5},
#  {'text': 'happy birthday zezi @czanne_lopez sana gamitin mo lagi regalo ko, and sana maging photogenic na ulit tayo HAHA 😶 https://t.co/Xe6DyDJ4HP',
#   'user': 'nigel_polite',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5},
#  {'text': 'Happy #InternationalSchoolMealsDay from our wonderful catering team @lunchtimeco @IntSchoolMeals https://t.co/BjE0ivpMql',
#   'user': 'GtWilbrahamSch',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.9},
#  {'text': 'RT @SecretarySonny: On behalf of the entire @USDA family, Happy National Ag Day, one and all! #NationalAgDay https://t.co/n1YWKA3QtK',
#   'user': 'JanCeesVogelaar',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5},
#  {'text': "RT @theBrightMoon97: 180722 동자아트홀 팬싸\n\nHappy White Valentine's Day💫\n#세븐틴 #SEVENTEEN #The8 #디에잇 #徐明浩 #서명호 @pledis_17 https://t.co/YSTxWPgqPj",
#   'user': 'GYUHAO11',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @realDonaldTrump: Happy National Ag Day! https://t.co/hNkOh0TqvW',
#   'user': 'qapplecroft6',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @PhysicsNews: Happy birthday Albert Einstein, born #onthisday in 1879. https://t.co/hzb7jHhV1z',
#   'user': 'dimas_______',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'xxx_amamc',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @BT21_: Cutie-pie 😋\n#Happy #PiDay \n#NeverEnding #Stories of #BT21 https://t.co/AI3SEWofAZ',
#   'user': 'Sandraa1029',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @JAEHYUNGPARKlAN: be healthy and happy, please. https://t.co/E91hYb5DMI',
#   'user': 'xxjrwrkxx',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.65},
#  {'text': 'RT @mirrandakerri: Happy birthday to my pretty gf!! Love u s’much 💋💋😘😘 https://t.co/6kTC8nGK3U',
#   'user': 'spainkristin',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.47265625},
#  {'text': 'RT @realDonaldTrump: Happy National Ag Day! https://t.co/hNkOh0TqvW',
#   'user': 'AgentFlush009',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': "RT @havoktreeftw: Seungcheol: Thanks for liking my first Instagram post Hoonie 😊\n\nJihoon: ....That wasn't-\n\nSeungcheol: And welcoming me! T…",
#   'user': 'bubjunhui',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.25625},
#  {'text': '@mCKyNEj33BKwhpu 今帰ってきたんでちょい作ってくるッス←',
#   'user': 'happy_wakame',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @lovefrom9697: #แจเตนล์กินอะไร\nก็แค่กินน้ำเปล่า ขวดเดียวกัน กินต่อกันไง #jaeten , happy white day นะคะทุกคน \U0001f9e1💜💚🌹 https://t.co/D7rtoEWm6u',
#   'user': 'mkmkiss',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'Happy #PiDay! https://t.co/tqjd4ALFC1',
#   'user': 'mmagnarelli',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @meikoi_app: ランクアップガチャ\n「HAPPY WHITE DAY ～mint&amp;strawberry～」開催中！\n\n鴎外たち８人の\n\n💙ホワイトデー着せ替え\n💚ホワイトデーメッセージ\n💜録りおろしボイス(CV:#浪川大輔）をGETしよう✨\n\n👇インストールはこ…',
#   'user': 'n_tyosu_0730',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @BenjaminLartei: Happy birthday to you Almighty @StreetBeatzWW \nMore blessings bossman. 🎂🎂🎂 https://t.co/ZJLjt85gmR',
#   'user': 'StreetBeatzWW',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.65},
#  {'text': 'Good morning Mets fans, and happy Pi Day! To celebrate, we’re giving away this Conforto signed ball. Keep an eye on… https://t.co/LJBsYaz2fi',
#   'user': 'stluciemets',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.85}]

# %%
client.get_sentiment('good,good,good,')
# Out:
# ('neutral', 0.0)

# %%
from flask import Flask, request, render_template, jsonify 
from werkzeug.wrappers import Request, Response

app = Flask(__name__)
api = TwitterClient()  
@app.route('/')
def index():
    return render_template('index.html')


@app.route('/tweets')
def tweets():
        query = request.args.get('query')
        tweets = api.get_tweets(query)
        return jsonify({'data': tweets, 'count': len(tweets)})


port = 5005
#app.run(host="0.0.0.0", port=port, debug=True)
from werkzeug.serving import run_simple
run_simple('0.0.0.0', port, app)
