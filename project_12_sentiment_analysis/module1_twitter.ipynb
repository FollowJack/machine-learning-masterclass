# %%
import tweepy
from textblob import TextBlob

# %%
# Step 1 - Authenticate
consumer_key= 'Z3dK7LmOsfjxY0wUDRrhzhtuf'
consumer_secret= 'pCSoTeyTV9vqocSAPC4YroFGguWbYC994G68DSpFpivb4kzQBG'

access_token='917532542949085189-WmnK90WIkLVblHTavb1oS70rFvckZd7'
access_token_secret='nqqMIGpS3n6p0Grf34PxZqmi331Ngfl6I4NKexWx9Fcs9'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
#Step 3 - Retrieve Tweets
public_tweets = api.search('Bad')

#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself


for tweet in public_tweets:
    print(tweet.text)
    print('Analysis')
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    if analysis.sentiment.polarity >= 0.2:
        print('Positiv')
    elif analysis.sentiment.polarity <= -0.2:
        print('Negativ')
    else:
        print('Neutral')
    print("")
# Out:
# you broke me so bad that I can’t feel for you anymore.💙
# Analysis
# Negativ
#
# RT @wgbh: In addition to being digitally archived for generations to come by our friends at @amarchivepub, your favorite characters from @s…
# Analysis
# Positiv
#
# things i'm bad at:
#
# 1. being attractive
# 2. being normal
# 3. accounting
# 4. texting back
# Analysis
# Neutral
#
# RT @redsidefthemoon: imma keep going I know she’s more talented than what romcoms call for but I want a soft wlw movie with her, a real que…
# Analysis
# Positiv
#
# RT @lamelang: rt or 10 years of bad luck https://t.co/gffg9yooCf
# Analysis
# Negativ
#
# @ezralevant I thought yesterday maybe Cambridge were having a bad day but even Clemens is an imbecile
# Analysis
# Negativ
#
# RT @migold: The measles outbreak is so bad that a New York county stopped unvaccinated kids from going to school.
#
# Parents sued to get thei…
# Analysis
# Negativ
#
# RT @renu_narula: #SayNoToGambling
# @derasachasauda volunteers hv pledged not 2 indulge in this bad habit.
# They take out rallies 2 aware ppl…
# Analysis
# Negativ
#
# RT @goudiaby_sophie: #OnePlanetSummit  Le Président Macron, la DSG Amina Mohamed, le Président Kenyatta la Banque mondiale et la BAD signen…
# Analysis
# Negativ
#
# @political_ellie Mono is so bad. I had it in 7th grade and was out for 2 months. I had to go to the hospital three… https://t.co/WLnfLD2vdU
# Analysis
# Negativ
#
# RT @SykesCharlie: We’re not talking about a night of binge drinking bad liquor at St. George’s. His serial insults, slurs, and bad takes on…
# Analysis
# Negativ
#
# "Pls. Stop using people to attain your needs and making my reputation continuously bad."
# #Formytoxicx https://t.co/BUlUQV9272
# Analysis
# Negativ
#
# RT @gavinesler: Three times in a few weeks MPs get to vote on the same Brexitshambles- and after almost 3 years the British people have cha…
# Analysis
# Neutral

# %% [markdown]
# # Playfield for Twitter Client

# %%
'''
Generic Twitter Class for the App
'''
class TwitterClient:
    def __init__(self):
        consumer_key= 'Z3dK7LmOsfjxY0wUDRrhzhtuf'
        consumer_secret= 'pCSoTeyTV9vqocSAPC4YroFGguWbYC994G68DSpFpivb4kzQBG'
        access_token='917532542949085189-WmnK90WIkLVblHTavb1oS70rFvckZd7'
        access_token_secret='nqqMIGpS3n6p0Grf34PxZqmi331Ngfl6I4NKexWx9Fcs9'
   
        self.auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        self.auth.set_access_token(access_token, access_token_secret)
        self.api = tweepy.API(self.auth)
        self.tweet_n_max = 100
        
    def get_tweets(self, query):
        tweets = []
        raw_tweets = self.api.search(q=query, count=self.tweet_n_max)

        for tweet in raw_tweets:
            parsed_tweet = {}
            parsed_tweet['text'] = tweet.text
            parsed_tweet['user'] = tweet.user.screen_name
            sentiment = self.get_sentiment(tweet.text)
            parsed_tweet['sentiment_status'] = sentiment[0]
            parsed_tweet['sentiment_polarity'] = sentiment[1]
            
            tweets.append(parsed_tweet)
        
        return tweets
    
    def get_sentiment(self, tweet_text):
        analysis = TextBlob(tweet_text)
        if analysis.sentiment.polarity > 0:
            return ('positive',analysis.sentiment.polarity)
        elif analysis.sentiment.polarity < 0:
            return ('negative',analysis.sentiment.polarity)
        return ('neutral',analysis.sentiment.polarity)

client = TwitterClient()
client

# %%
client.get_tweets('happy')
# Out:
# [{'text': 'RT @neiltyson: March 14th. (3.14)\n\nHappy Pi day to pi-maniacs out there.',
#   'user': 'ITYS589',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @Swamy39: I am happy that finally BJP media campaign has is now getting focused on Corruption of Congi leaders TDK Buddhu Bottle Goon Pu…',
#   'user': 'harpreet7895',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': '@55mmbae Lol you sound happy 😂',
#   'user': '__WillTyson93',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.6666666666666666},
#  {'text': "RT @fizhasan: So happy to see all JH ex-fans in my TL think the same as me.\n\nThere's no excuse for whatever you did, dude.\n\nYou're sick.\n\nA…",
#   'user': 'rbyjnk',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.02767857142857144},
#  {'text': 'グッズ厨少し降りようと思うんで\n坂田とかのグッズもろもろだれかいりませんかー',
#   'user': 'happy_oOsa_vV',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @billlcy61: Chanyeol dimple\nChanyeol smile\nChanyeol happy\nChanyeol handsome\nChanyeol lovely\nChanyeol charming\nChanyeol guitar\nChanyeol d…',
#   'user': 'xmminijok',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5599999999999999},
#  {'text': 'RT @BT21_: Cutie-pie 😋\n#Happy #PiDay \n#NeverEnding #Stories of #BT21 https://t.co/AI3SEWofAZ',
#   'user': 'saratenoriovel2',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @cleannevlnc: I can’t with my mama 😭 MY HEART IS FULL AND HAPPY 💗 So much for my own grad speech, this is enough!!! My mama deserve this…',
#   'user': 'niicoonicooniii',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.38999999999999996},
#  {'text': 'RT @BT21_: Cutie-pie 😋\n#Happy #PiDay \n#NeverEnding #Stories of #BT21 https://t.co/AI3SEWofAZ',
#   'user': 'Phattt16',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @sofia_abellera: Happy chemicals pls 🌟💖💐 https://t.co/JF9XuO7tvX',
#   'user': 'navarrinhos',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'Happy #PiDay. We are looking forward to spring so we can watch the cherries start to blossom so we can make a delic… https://t.co/38x0xb8zlf',
#   'user': 'madcoPH',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @ariasonnata: @arkmassei Happy Birthday pooo. ~sfc',
#   'user': 'arkmassei',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@EB_Asbr Ahh ok, happy belated!!',
#   'user': 'im2nd2none',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.75},
#  {'text': "RT @sodubaeb: What Jinyoung said:\n\nToday's event was such a pity (bc it was short), but I was really happy to be able to meet everyone toda…",
#   'user': 'bejinyoungs',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.24000000000000005},
#  {'text': "I'm glad to know that my simple efforts makes you happy.  😊",
#   'user': 'grldn4gstn',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.43333333333333335},
#  {'text': 'Happy national pie day 3.14 https://t.co/ohFYFdR8p3',
#   'user': 'ford_mikal',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @MnetKR: 190214 #MCOUNTDOWN 포토타임\n♥HAPPY VALENTINE’S DAY♥\n#에이티즈 #ATEEZ @ATEEZofficial https://t.co/JVZy3eQd27',
#   'user': 'lazouu_V',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @Maricel43651601: @MaichardArmy 💃💃💃💃💃💃💃na tyo mga kapanalig sa 2 yeheeeeeyyyyyyy ika nga eh YOU AND ME HAPPY TOGETHER!!!!#ADN191stWeeksa…',
#   'user': 'nenen8888',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @Kunworld802: ยีงเหลืออีกเยอะเลยจ้า ใครจะเอา\nมาเลย แจกจ้า แจกกกก ออกค่าส่งเองเท่านั้นจ้า \n\nฝากรีด้วยนะจ้าา\n#BTSLoveYourselfBKK\n#BTSLoveY…',
#   'user': 'taetaewtntnt',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @cerila_m_dc: @MaichardArmy Wala makikialam, tuloy mo lang yan, at happy kami.\n#ADN191stWeeksary',
#   'user': 'mxsara',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @ifseng: 스물여섯 #셍일광고 4번째☁️\n190314 건대입구역 by.@sun_and_moon322\n\nHappy Sungwoon day💕\n\n타이밍맞추기 힘들어서\n오르락내리락 왔다갔다🕺🏻💃\n\n#하성운 #河成云 #ハソンウン\n#하버드 #셍일투어…',
#   'user': 'sun_and_moon322',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'yutaya',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @cassawass: Happy pi day @l8rpeasants hope ur day is a delicious as pie',
#   'user': 'cassawass',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.9},
#  {'text': 'RT @neiltyson: March 14th. (3.14)\n\nHappy Pi day to pi-maniacs out there.',
#   'user': 'eXistenZforNOW',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@kdrama_menfess Iyaaa. Dia emang suka notice fansnya dia blg di happy together baik bgt ya :(',
#   'user': 'geulliteo',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.025000000000000022},
#  {'text': 'RT @argturuinmd: 20190314\nhappy white day https://t.co/6oPIamBnXg',
#   'user': 'Robota013',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': 'jiab023',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@sasha_stana @dlsquared2 @AnaMSL4ever @L0B033 @pisceaneanangel @VaneBailly @DianaRuthRodri5 @JoXenite75… https://t.co/TkhSUa8Wi5',
#   'user': 'ines2464',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @aleajmarie: @yokacameeel HAPPY BIRTHDAY EUCAA! \U0001f973\U0001f973\U0001f973',
#   'user': 'yokacameeel',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': '@ZESalz Joke lang zraaaaa, HAPPY BIRTHDAAAAY💖🎉🎊',
#   'user': 'KJPorras',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @neiltyson: March 14th. (3.14)\n\nHappy Pi day to pi-maniacs out there.',
#   'user': 'amfit_1',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @jos_Angeloo: seeing my parents happy, \n⠀\n⠀\n⠀\n⠀\n⠀\n\n      ⠀\n           \n⠀      ᵐᵃᵏᵉˢ ᵐᵉ ᵉᵛᵉⁿ ᵐᵒʳᵉ ʰᵃᵖᵖʸ\n⠀⠀⠀            \n        \n⠀\n⠀\n⠀\n⠀…',
#   'user': 'padilladanrous',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @mamman_uthman: Happy birthday. More blessings bruhh @hasheem_rayyan',
#   'user': 'hasheem_rayyan',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.65},
#  {'text': 'RT @_its_julia42: Okay but like why is Anna my twin separated at birth! Happy 18th babe! https://t.co/QXFLObdhiS',
#   'user': 'AnnaEsterly',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8125},
#  {'text': 'RT @otodoke_kareshi: 【おとどけカレシ♥Happy Whiteday①】 \nおむかえカノジョのみなさま、ハッピーホワイトデー！\nということで晴日 青先生書き下ろしSSを公開！\nトップバッターはナンバーワンおとどけカレシ瀬戸仁（CV：木村良平）です！\n #オト…',
#   'user': 'TsubakiHibino87',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @CFCBlues_com: Happy 40th Birthday Nicolas Anelka! 🔵\n\nWill never forget his 08-09 season, what a player 🙌\n\n👤 184 apps\n⚽ 59 goals\n🏆🏆 FA C…',
#   'user': 'DRadjikin',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'Happy Book Birthday / Launch Day to Dead Heat by Ren the Writer from Mocha Memoirs Press! We’re so excited to annou… https://t.co/iyWWmgLY6V',
#   'user': 'mochamemoirs',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.30833333333333335},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'yav_han',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': "6yo: Numbers go on forever but alphabet only has 26 letters, right dad?\n\nMe: I'm afraid so son, I'm afraid so. *hea… https://t.co/eKD3JKDSEM",
#   'user': 'jeffwilsontech',
#   'sentiment_status': 'negative',
#   'sentiment_polarity': -0.22857142857142856},
#  {'text': 'RT @jos_Angeloo: seeing my parents happy, \n⠀\n⠀\n⠀\n⠀\n⠀\n\n      ⠀\n           \n⠀      ᵐᵃᵏᵉˢ ᵐᵉ ᵉᵛᵉⁿ ᵐᵒʳᵉ ʰᵃᵖᵖʸ\n⠀⠀⠀            \n        \n⠀\n⠀\n⠀\n⠀…',
#   'user': '_KianMndp',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @therampagefext: 🌸🌸🌸\n\nHappy  White Day!!✨\n\n今日はホワイトデー☺️👏✨\n\n日頃から支えて頂いている皆さんへ、僕からの気持ちをお返しです🙏✨\n\n皆さまにとって素敵な一日になりますように🙏✨\n\nLove❤︎\n\n川村壱馬\n\n#THERA…',
#   'user': '_1016karats',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': '@_DomoWilson1 Happy 2nd bday Wick🎂🎂🎂🎂🎂🎂',
#   'user': 'British29473074',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @rsllrasd: We’re now one step closer to P.I.C.C. 🙏🏻☝🏻 \n\nTHANKYOU GOD! I’M SO HAPPY AND BLESSED THAT I AM A PART OF THIS FAMILY.😭❣️ LOVE…',
#   'user': 'peindlvlle',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': '@HTimber Happy Birthday. Can’t wait to pop in when I’m in London in September',
#   'user': 'icarusjhb',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @ygent_official: HAPPY BIRTHDAY #JIHOON 🎉\n\n#TREASURE13 #트레저13 #PARKJIHOON #박지훈 #HAPPYBIRTHDAY #YG https://t.co/F3aZMT2WHf',
#   'user': 'ninininicss',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'This year i will you get to yourself to be happy to be with me this week I can imagine how much you wanna I know I… https://t.co/j1LeW60wKO',
#   'user': 'niezmri',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': '_chittaphrrrr',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @ChrisEvans: Technically it’s YOUR umbrella. But I’m happy to hold it. https://t.co/tFqWFqCSv3',
#   'user': 'CarolMschneider',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': "RT @karoruru: Koga: Oi, oi!! Morisawa-senpai! Are you okay?!\n\nChiaki: ..uu...O...Oogami....I can't...go on anymore..... I was happy to.....…",
#   'user': 'oumakira',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.7125},
#  {'text': '@pcysarchive Chanyeol our happy virus!!!!',
#   'user': 'aeripearl_loey',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': "RT @eatmeanthony: HOW TO MAKE A GIRL'S HEART HAPPY.\n-Talk to her about your life.\n-Send her your selfies (wacky and epic pictures)\n-Always…",
#   'user': 'theafrncne',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.46666666666666673},
#  {'text': 'RT @Hope17My: Good morning ☀️ and happy Thursday, fam! \n\nIsn’t it amazing to be part of a fandom where the boys are so precious and really…',
#   'user': 'trulyatrivia',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.7},
#  {'text': 'RT @Namo1154: I love you more than words can describe \n\nHappy Thai Elephant Day \n #วันช้างไทย https://t.co/pgGybOQww2',
#   'user': 'Nikkyhadi',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.6},
#  {'text': 'RT @BiKeR626: Guys you know sometimes when things happen for other people it’s so difficult to be genuinely happy for them because you keep…',
#   'user': 'katleho_mathe',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.05833333333333335},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': 'helixhani',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @zweidosenbier: happy birthday @MIIRABILIS ! have a great day, ly!',
#   'user': 'MIIRABILIS',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @mankai_stage: 💐✨🎀✨Happy WhiteDay✨🎀✨💐\n\n本日3月14日は💙🍭🍪ホワイトデー🍪🍭💙エーステカンパニーから監督さんへありがとうの気持ちをたくさん込めてお返しをお届けします❣\u3000\n\n#エーステ #ホワイトデー https://t.co/3v5…',
#   'user': '1092mikity',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @myhero_info: 【Happy Birthday🎂】\n３月１４日は可愛ひかるの誕生日🎉\n\n可愛\n「あ、また『かわいい』って言った」\n「かわいいだけの可愛ひかる、じゃないんだよ」\n「僕の目を見て…そう、それで教えて。僕、本当にかわいいだけ？」\n\n（キャラクター原画…',
#   'user': 'frmk_luv',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @ChelseaFC: Happy birthday, Nicolas Anelka! 🎈 https://t.co/FDyFYRghKU',
#   'user': 'brownkrypton12',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @BT21_: Cutie-pie 😋\n#Happy #PiDay \n#NeverEnding #Stories of #BT21 https://t.co/AI3SEWofAZ',
#   'user': 'Kookiezinha_Geo',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @Itsemstangonan: Happy 60k🎆 game follow na ko 60 peopleee🔁',
#   'user': 'fhlmrc_bgrn',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.2},
#  {'text': 'RT @sleeepyrabbit_: Our spring blooms...\nI think I need a Kdrama like this lol\nOh, and happy white day!\n#taekook https://t.co/rfEjUXXKE4',
#   'user': '__btst1230',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5333333333333333},
#  {'text': '@1KINGBOW happy birthdaay',
#   'user': 'Sudsdoe',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @mefeater: Happy 47th Birthday to Common 🖤 https://t.co/4al1pYHt0R',
#   'user': 'Ms_luyanda',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.25},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'knndest301',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': "RT @BankyW: Breaking news: My wife is on the cover of @voguemagazine!!!!!!!!!!\n\n @AdesuaEtomiW you are such an inspiration!!! I'm soooo PRO…",
#   'user': 'Binanii',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'Atlı karınca sanat etkinliğimiz ☺️🐴 #at #atlıkarınca #etkinlik #sanatetkinliği #anaokulu#preschool#activites#school… https://t.co/aOujSYNmFY',
#   'user': 'KatreCocuk',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': 'Natansoo',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': 'jaemin00magicx',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'Happy Pi Day!!! https://t.co/hGXvesTgvv',
#   'user': 'jgonz1973',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'cell8787',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @exotakemymoney: HAPPY SEHUN DAY💚\n\n세훈이의 26번째 생일을 기념하여 컵홀더 이벤트 진행합니다.\n\n#싱그러운_봄에_우리_곁에_왔세훈\n\n★이 트윗을 RT해주신 분들 중 추첨을 통해 선물을 드립니다.\n\n자세한 사항은 타래…',
#   'user': 'berry5_6',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'Happy birthday to 2x MVP &amp; Greatest shooter of all time 💖👨\u200d🍳 @StephenCurry30',
#   'user': 'ElmerDomingooo',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.9},
#  {'text': "When your 9-6 is over, it's time to get pampered! This is our happy hour\n\nانتهى الدوام وحان وقت الراحة! هذه رفاهيتن… https://t.co/Rs0dKzflUT",
#   'user': 'VWDubai',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @NCTsmtown: Happy Birthday!!!!🎂My idol～SC 30！🎈🎈 https://t.co/X0FcjmiHcc',
#   'user': 'darkesten',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @motorway0214: happy white day🎩\n\n#NCT127 #재현 #JAEHYUN https://t.co/OHBz3PxBYV',
#   'user': 'souljuuu',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'goyoBJD',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'Advice na mahirap gawin\n\n"always be happy"',
#   'user': 'mrkchrstnlgdr',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'Happy Gday To My Cous Kelz',
#   'user': 'Loyaltylove_Kb',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @hilmikhai_: Tengok kawan -kawan happy pun dah cukup buat kita happy walaupun deep inside we are crying and dying .  Stay strong you guy…',
#   'user': '_ayuntsya',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.3666666666666667},
#  {'text': 'RT @granbluefantasy: 【グランブルーファンタジー】Happy White Day！グラブルイラストレーターから、ホワイトデーのイラストをお届け！！ 本日より3/22(金)20:59までゲーム内にて「HAPPY White Day!」キャンペーンを開催中です！…',
#   'user': 'VwEU5d5SdWEj471',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': '@isaacmashman Happy Birthday to your mom',
#   'user': 'bowling23',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.8},
#  {'text': 'RT @AdventreTime: Happy birthday, Finn! https://t.co/qnLW6FsUpl',
#   'user': 'lindsey13800791',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @sleeepyrabbit_: Our spring blooms...\nI think I need a Kdrama like this lol\nOh, and happy white day!\n#taekook https://t.co/rfEjUXXKE4',
#   'user': 'daegudust',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.5333333333333333},
#  {'text': 'Happy Π Day to all my Sigma Pi Brothers!',
#   'user': 'GrandSage43',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @ara_mackey: HAPPY WHITE DAY！🍫',
#   'user': 'puwa_shi_ju',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @ChrisEvans: Technically it’s YOUR umbrella. But I’m happy to hold it. https://t.co/tFqWFqCSv3',
#   'user': 'fxnathi',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @FRONZ1LLA: if ur ever mad about a situation just think about this.... ur gonna die one day so who cares? be happy 😊',
#   'user': 'Ensleyn22',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.08750000000000002},
#  {'text': 'RT @East_cf: The joy is double today ✌ 🎊 The joy of happy Weekend and the joy of launching the #EasternSeason and today we will say altoget…',
#   'user': 'bdbdp2',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.64},
#  {'text': 'RT @woye1: We should be angry with ENI / SHELL trial as Nigerians if u know how much involved. Our NASS should have raised RED FLAG but no.…',
#   'user': 'AlabaOginni',
#   'sentiment_status': 'negative',
#   'sentiment_polarity': -0.09999999999999999},
#  {'text': '@MassimoSt @ComplexMentis @csqsiew Hey\nIs it still actual?\nWe would be happy to help to distribute it, but saw it too late..',
#   'user': 'NetworkScied',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.16666666666666666},
#  {'text': 'RT @mankai_stage: 💐✨🎀✨Happy WhiteDay✨🎀✨💐\n\n本日3月14日は💙🍭🍪ホワイトデー🍪🍭💙エーステカンパニーから監督さんへありがとうの気持ちをたくさん込めてお返しをお届けします❣\u3000\n\n#エーステ #ホワイトデー https://t.co/3v5…',
#   'user': 'orionnnnn0622',
#   'sentiment_status': 'neutral',
#   'sentiment_polarity': 0.0},
#  {'text': 'RT @WE_THE_BOYZ: [에릭] 해피 화이트 데이 💝\n           Happy White Day 🍭 https://t.co/e0HmSYFSJy',
#   'user': 'jacobskrave',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.01666666666666668},
#  {'text': 'RT @5hineonyou: Everyone FA said Jinki is in a realllllllyyy good mood and acting really cute ^^ he must be super happy that his parents wa…',
#   'user': 'TsMb4',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4666666666666666},
#  {'text': 'RT @ChrisEvans: Technically it’s YOUR umbrella. But I’m happy to hold it. https://t.co/tFqWFqCSv3',
#   'user': '1111bb1111',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4},
#  {'text': 'RT @BAEJINYOUNG_TH: [FANCAFE] 190314 แพจินยองได้โพสต์วิดีโอและข้อความในห้อง FROM. JINYOUNG เนื่องในวันไวท์เดย์ค่ะ🍫\n\nHAPPY WHITE DAY นะคะทุก…',
#   'user': 'Rabbitnote',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.01666666666666668},
#  {'text': '@MrsPete_Math @BrodyPeterson_ Happy birthday, Brody!!!',
#   'user': 'WelteTiffanie',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 1.0},
#  {'text': 'RT @Duc2Lady: Thanks for working hard.\nThanks for the good music, the good memories and the unconditional love.\nHappy 17th anniversary. 🤗💗🎵…',
#   'user': 'SDTD_JW',
#   'sentiment_status': 'positive',
#   'sentiment_polarity': 0.4011904761904762}]

# %%
client.get_sentiment('good,good,good,')
# Out:
# ('neutral', 0.0)
