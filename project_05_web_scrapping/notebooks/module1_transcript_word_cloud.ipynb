# %% [markdown]
# # Youtube transcript wordcloud

# %% [markdown]
# ## Summary
# - donwload script
# - data process text
# - filter stopwords
# - print wordcloud

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

# %%
# Setup dependencies
from youtube_transcript_api import YouTubeTranscriptApi

from wordcloud import WordCloud, get_single_color_func, ImageColorGenerator

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/deniel.horvatic/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# downlaod transcript
video_id = 'nSSSqJVTseA' # hOfRN0KihOU nSSSqJVTseA
content = YouTubeTranscriptApi.get_transcript(video_id)
content
# Out:
# [{'text': 'lange zeit ging die wissenschaft davon',
#   'start': 2.6,
#   'duration': 4.06},
#  {'text': 'aus dass sich das gehirn nicht mehr',
#   'start': 4.92,
#   'duration': 3.87},
#  {'text': 'verändern kann wenn die entstehung und',
#   'start': 6.66,
#   'duration': 3.72},
#  {'text': 'vernetzung von nervenzellen in der',
#   'start': 8.79,
#   'duration': 7.92},
#  {'text': 'kindheit abgeschlossen nun entdecken wir',
#   'start': 10.38,
#   'duration': 8.58},
#  {'text': 'das gehirn kann sich verändern', 'start': 16.71, 'duration': 5.93},
#  {'text': 'doch nicht jede veränderung ist gut',
#   'start': 18.96,
#   'duration': 5.909},
#  {'text': 'veränderungen im gehirn können uns krank',
#   'start': 22.64,
#   'duration': 4.62},
#  {'text': 'machen', 'start': 24.869, 'duration': 2.391},
#  {'text': 'romantische belastungsstörungen und',
#   'start': 29.24,
#   'duration': 5.55},
#  {'text': 'schizophrenie', 'start': 31.79, 'duration': 3.0},
# ...

# %%
text_content = [sentence['text'] for sentence in content]
text_string = ''.join(text_content)
text_string = text_string.split()
text_string
# Out:
# ['lange',
#  'zeit',
#  'ging',
#  'die',
#  'wissenschaft',
#  'davonaus',
#  'dass',
#  'sich',
#  'das',
#  'gehirn',
#  'nicht',
#  'mehrverändern',
#  'kann',
#  'wenn',
#  'die',
#  'entstehung',
#  'undvernetzung',
#  'von',
#  'nervenzellen',
#  'in',
#  'derkindheit',
#  'abgeschlossen',
#  'nun',
#  'entdecken',
#  'wirdas',
#  'gehirn',
#  'kann',
#  'sich',
#  'veränderndoch',
#  'nicht',
#  'jede',
#  'veränderung',
#  'ist',
#  'gutveränderungen',
#  'im',
#  'gehirn',
#  'können',
#  'uns',
#  'krankmachenromantische',
#  'belastungsstörungen',
#  'undschizophreniedank',
#  'unseres',
#  'wissens',
#  'um',
#  'die',
#  'formbarkeitdes',
#  'gehirns',
#  'entwickeln',
#  'wir',
#  'jetzt',
#  'neuebehandlungsformen',
#  'für',
#  'psychischeerkrankungen',
#  'und',
#  'störungendie',
#  'man',
#  'einst',
#  'für',
#  'unheilbar',
#  'hielt',
#  'manmuss',
#  'den',
#  'betroffenen',
#  'klar',
#  'machen',
#  'dassihr',
#  'gehirn',
#  'ihnen',
#  'einfach',
# ...

# %%
# filter stop words
filtered_words = [word for word in text_string if word not in stopwords.words('german')]
final_text = ' '.join(filtered_words)
final_text
# Out:
# 'lange zeit ging wissenschaft davonaus dass gehirn mehrverändern entstehung undvernetzung nervenzellen derkindheit abgeschlossen entdecken wirdas gehirn veränderndoch veränderung gutveränderungen gehirn krankmachenromantische belastungsstörungen undschizophreniedank wissens formbarkeitdes gehirns entwickeln neuebehandlungsformen psychischeerkrankungen störungendie einst unheilbar hielt manmuss betroffenen klar dassihr gehirn einfach falschmeldungenschicktisch dr enormen deutsch buchgeschrieben neustart kopf sichunser gehirn repariert dieentdeckung neuroplastizität dieerkenntnis dass gehirn alleindurch denkprozesse strukturell undfunktional verändern kannsie stellt bedeutendsten wandel imverständnis gehirns dar 400jahre lang dachten gehirn wäreso verschiedenenteilen bestehende maschine diesemechanistische sichtweise bedeutete dassmenschen hirnschadengeboren wurden laufe ihreslebens hirnschaden erlitten dazuverdammt leben dennmaschinen vieles neueersatzteile wachsen lassen sienicht neu
# ...

# %%
# print wordcloud
wordcloud = WordCloud(max_font_size=40).generate(final_text)
plt.figure(figsize=(24,24))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ---
#
# # In the following just some random tests

# %%
import sys
# !{sys.executable} -m pip install --user beautifulsoup4
# !{sys.executable} -m pip install --user selenium

# %%
sys.executable
# '/usr/local/opt/python/bin/python3.7'
#  /usr/local/lib/python3.7/site-packages/pip terminal
# Out:
# '/usr/local/Cellar/python/3.7.2_2/bin/python3.7'

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.youtube.com/watch?v=nSSSqJVTseA"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html><html lang="de" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:\'Roboto\';font-style:italic;font-weight:400;src:local(\'Roboto Italic\'),local(\'Roboto-Italic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:500;src:local(\'Roboto Medium Italic\'),local(\'Roboto-MediumItalic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:400;src:local(\'Roboto Regular\'),local(\'Roboto-Regular\'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:500;src:local(\'Roboto Medium\'),local(\'Roboto-Medium\'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format(\'truetype\');}</style><script name="www-roboto" >if (document.fon
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html data-cast-api-enabled="true" lang="de">\n <head>\n  <style name="www-roboto">\n   @font-face{font-family:\'Roboto\';font-style:italic;font-weight:400;src:local(\'Roboto Italic\'),local(\'Roboto-Italic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:500;src:local(\'Roboto Medium Italic\'),local(\'Roboto-MediumItalic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:400;src:local(\'Roboto Regular\'),local(\'Roboto-Regular\'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:500;src:local(\'Roboto Medium\'),local(\'Roboto-Medium\'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format(\'truetype\');}\n  </style>\n  <script name="www-robot
# ...

# %%
soup.find_all(class_='style-scope')
# Out:
# []

# %%
video_id = 'nSSSqJVTseA'
url = "http://video.google.com/timedtext?lang=de&v={}".format(video_id)
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b''

# %%
video_id = 'nSSSqJVTseA'
url = "http://video.google.com/timedtext?lang=de&v={}".format(video_id)
url
# Out:
# 'http://video.google.com/timedtext?lang=de&v=nSSSqJVTseA'

# %%
# url = 'https://www.youtube.com/watch?v=nSSSqJVTseA'
# from bs4 import BeautifulSoup
# from selenium import webdriver
# driver = webdriver.Firefox(executable_path = '/Users/followjack/Documents/geckodriver/geckodriver')
# driver.get(url)

# html = driver.page_source
# soup = BeautifulSoup(html)

# soup.contents
# check out the docs for the kinds of things you can do with 'find_all'
# this (untested) snippet should find tags with a specific class ID
# see: http://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-by-css-class

# %%
# for tag in soup.find_all("div", class_="cue style-scope ytd-transcript-body-renderer"):
#     print(tag)

# %%
from youtube_transcript_api import YouTubeTranscriptApi
video_id = 'hOfRN0KihOU' # hOfRN0KihOU nSSSqJVTseA
content = YouTubeTranscriptApi.get_transcript(video_id)

# %%
content
# Out:
# [{'text': 'Mekanizmat e evolucionit', 'start': 3.489, 'duration': 3.677},
#  {'text': 'Cfare eshte evolucioni?', 'start': 7.166, 'duration': 2.892},
#  {'text': 'Evolucioni eshte zhvillimi i jets ne planetin Toke',
#   'start': 10.058,
#   'duration': 3.75},
#  {'text': 'Ky eshte nje proces qe filloi miliona vjet me perpara dhe ende vazhdon.',
#   'start': 13.808,
#   'duration': 6.25},
#  {'text': 'Evolucioni na shpjegon se si eshte i mundur zhvillimi i diversitetit te formave jetesore.',
#   'start': 20.058,
#   'duration': 5.471},
#  {'text': 'Ai na shpjegon se si protozoaret primitiv arriten te behen miliona prej specieve te ndryshme qe njihen sot.',
#   'start': 25.529,
#   'duration': 8.305},
#  {'text': 'Evolucioni,pra,eshte pergjigjia e pyetjes qe te gjithe kemi pyetur  kur kemi pare nje Dashund dhe nje Danez te madh sebashku:',
#   'start': 33.834,
#   'duration': 8.662},
#  {'text': 'Si eshte e mundur qe te kete pasardhes qe duken kaq te ndryshem nga njeri tjetri?',
# ...

# %%
text_content = [sentence['text'] for sentence in content]
text_string = ''.join(text_content)
text_string = text_string.split()
from wordcloud import WordCloud, get_single_color_func, ImageColorGenerator
import numpy as np
import matplotlib
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
filtered_words = [word for word in text_string if word not in stopwords.words('german')]
final_text = ' '.join(filtered_words)
final_text
import matplotlib.pyplot as plt

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(final_text)
plt.figure(figsize=(24,24))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/deniel.horvatic/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from wordcloud import WordCloud, get_single_color_func, ImageColorGenerator
import numpy as np
import matplotlib

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
filtered_words = [word for word in text_string if word not in stopwords.words('german')]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/deniel.horvatic/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
filtered_words
# Out:
# ['Mekanizmat',
#  'e',
#  'evolucionitCfare',
#  'eshte',
#  'evolucioni?Evolucioni',
#  'eshte',
#  'zhvillimi',
#  'i',
#  'jets',
#  'ne',
#  'planetin',
#  'TokeKy',
#  'eshte',
#  'nje',
#  'proces',
#  'qe',
#  'filloi',
#  'miliona',
#  'vjet',
#  'me',
#  'perpara',
#  'dhe',
#  'ende',
#  'vazhdon.Evolucioni',
#  'na',
#  'shpjegon',
#  'se',
#  'si',
#  'eshte',
#  'i',
#  'mundur',
#  'zhvillimi',
#  'i',
#  'diversitetit',
#  'te',
#  'formave',
#  'jetesore.Ai',
#  'na',
#  'shpjegon',
#  'se',
#  'si',
#  'protozoaret',
#  'primitiv',
#  'arriten',
#  'te',
#  'behen',
#  'miliona',
#  'prej',
#  'specieve',
#  'te',
#  'ndryshme',
#  'qe',
#  'njihen',
#  'sot.Evolucioni,pra,eshte',
#  'pergjigjia',
#  'e',
#  'pyetjes',
#  'qe',
#  'te',
#  'gjithe',
#  'kemi',
#  'pyetur',
#  'kur',
#  'kemi',
#  'pare',
#  'nje',
#  'Dashund',
#  'dhe',
#  'nje',
#  'Danez',
#  'te',
#  'madh',
#  'sebashku:Si',
#  'eshte',
#  'e',
#  'mundur',
#  'qe',
#  'te',
#  'kete',
# ...

# %%
final_text = ' '.join(filtered_words)
final_text
# Out:
# 'Mekanizmat e evolucionitCfare eshte evolucioni?Evolucioni eshte zhvillimi i jets ne planetin TokeKy eshte nje proces qe filloi miliona vjet me perpara dhe ende vazhdon.Evolucioni na shpjegon se si eshte i mundur zhvillimi i diversitetit te formave jetesore.Ai na shpjegon se si protozoaret primitiv arriten te behen miliona prej specieve te ndryshme qe njihen sot.Evolucioni,pra,eshte pergjigjia e pyetjes qe te gjithe kemi pyetur kur kemi pare nje Dashund dhe nje Danez te madh sebashku:Si eshte e mundur qe te kete pasardhes qe duken kaq te ndryshem nga njeri tjetri?Per t\'iu pergjigjur kesaj pyetjeje do fokusohemi tek kafshet,pa perfshire kerpurdhat ose bimet.Pyetja e pare qe mund te pyesim rrjedhimisht eshte: Si mundet nje kafshe te zhvillohet ne nje specie krejt te re?Po ceshte nje specie ekzaktesisht?Nje specie eshte nje grup kafshesh te cilat jane te afta te riprodhohen dhe te lindin pasardhesDhe keta pasardhes jane ne gjendje te riprodhohen perseri per te dhene pasardhes te tjere.
# ...

# %%
import matplotlib.pyplot as plt

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(final_text)
plt.figure(figsize=(24,24))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# https://github.com/jdepoix/youtube-transcript-api/blob/master/youtube_transcript_api/_api.py
