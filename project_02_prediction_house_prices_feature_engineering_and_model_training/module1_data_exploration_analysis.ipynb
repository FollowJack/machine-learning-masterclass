# %% [markdown]
# # Data Exploration Analysis
# ## Summary
# - explore datatypes of dataframe
# - used describe, head and tail for inspection
# - plot histogram of dataframe
# - use seaborn countplot for category ('object') overview of a feature
# - use searborn boxplot to see segmentation for observing relationships between categorial and numerical features
# - see correlations (with df.corr()) as heatmaps between features to inspect independent features with sea

# %% [markdown]
# ### Setup Dependencies

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv('data/real_estate_data.csv')

# %% [markdown]
# ### Inspect Dataset

# %%
# dataframe dimensions
df.shape
# Out:
# (1883, 26)

# %%
# column datatypes
df.dtypes
# Out:
# tx_price                int64
# beds                    int64
# baths                   int64
# sqft                    int64
# year_built              int64
# lot_size                int64
# property_type          object
# exterior_walls         object
# roof                   object
# basement              float64
# restaurants             int64
# groceries               int64
# nightlife               int64
# cafes                   int64
# shopping                int64
# arts_entertainment      int64
# beauty_spas             int64
# active_life             int64
# median_age            float64
# married               float64
# college_grad          float64
# property_tax          float64
# insurance             float64
# median_school         float64
# num_schools           float64
# tx_year                 int64
# dtype: object

# %%
# display 5 first rows
df[0:5]
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
# 2    279900     1      1   615        1963         0
# 3    379900     1      1   618        2000     33541
# 4    340000     1      1   634        1992         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
# 2  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 3  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 4  Apartment / Condo / Townhouse          Brick                  NaN
#
#    basement  restaurants  groceries  nightlife  cafes  shopping  \
# 0       NaN          107          9         30     19        89
# 1       1.0          105         15          6     13        87
# ...

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# property_type     object
# exterior_walls    object
# roof              object
# dtype: object

# %%
for features in df.dtypes[df.dtypes == 'object'].index:
    print(features)
# Out:
# property_type
# exterior_walls
# roof

# %%
df.head(10)
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
# 2    279900     1      1   615        1963         0
# 3    379900     1      1   618        2000     33541
# 4    340000     1      1   634        1992         0
# 5    265000     1      1   641        1947         0
# 6    240000     1      1   642        1944         0
# 7    388100     1      1   650        2000     33541
# 8    240000     1      1   660        1983         0
# 9    250000     1      1   664        1965         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
# 2  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 3  Apartment / Condo / Townhouse    Wood Siding                  NaN
# ...

# %%
df.tail()
# Out:
#       tx_price  beds  baths  sqft  year_built  lot_size  property_type  \
# 1878    385000     5      6  6381        2004    224334  Single-Family
# 1879    690000     5      6  6501        1956     23086  Single-Family
# 1880    600000     5      6  7064        1995    217800  Single-Family
# 1881    759900     5      6  7500        2006      8886  Single-Family
# 1882    735000     5      6  7515        1958     10497  Single-Family
#
#            exterior_walls                 roof  basement  restaurants  \
# 1878               Stucco  Composition Shingle       1.0            0
# 1879                Brick  Composition Shingle       1.0           45
# 1880                Metal  Composition Shingle       1.0            5
# 1881  Siding (Alum/Vinyl)              Asphalt       1.0           18
# 1882                Brick  Composition Shingle       1.0            0
#
#       groceries  nightlife  cafes  shopping  arts_entertainment  beauty_spas  \
# ...

# %% [markdown]
# ### Histogram

# %%
df.hist(xrot=-45, figsize=(14,14))
plt.show()

# %%
df.describe()
# Out:
#             tx_price         beds        baths         sqft   year_built  \
# count    1883.000000  1883.000000  1883.000000  1883.000000  1883.000000
# mean   422839.807754     3.420605     2.579926  2329.398832  1982.963887
# std    151462.593276     1.068554     0.945576  1336.991858    20.295945
# min    200000.000000     1.000000     1.000000   500.000000  1880.000000
# 25%    300000.000000     3.000000     2.000000  1345.000000  1970.000000
# 50%    392000.000000     3.000000     3.000000  1907.000000  1986.000000
# 75%    525000.000000     4.000000     3.000000  3005.000000  2000.000000
# max    800000.000000     5.000000     6.000000  8450.000000  2015.000000
#
#            lot_size  basement  restaurants    groceries    nightlife  \
# count  1.883000e+03    1657.0  1883.000000  1883.000000  1883.000000
# mean   1.339262e+04       1.0    40.210303     4.505045     5.074881
# std    4.494930e+04       0.0    46.867012     4.491029     8.464668
# ...

# %% [markdown]
# ### Count Plots
# For data that is categorical

# %%
# display summary statistics for categorial features
df.describe(include=['object'])
# Out:
#         property_type exterior_walls                 roof
# count            1883           1660                 1529
# unique              2             16                   16
# top     Single-Family          Brick  Composition Shingle
# freq             1080            687                 1179

# %%
df.describe(include=['float64'])
# Out:
#        basement   median_age      married  college_grad  property_tax  \
# count    1657.0  1883.000000  1883.000000   1883.000000   1883.000000
# mean        1.0    38.601168    69.091875     65.085502    466.777483
# std         0.0     6.634110    19.659767     16.953165    231.656645
# min         1.0    22.000000    11.000000      5.000000     88.000000
# 25%         1.0    33.000000    58.000000     54.000000    320.000000
# 50%         1.0    38.000000    73.000000     66.000000    426.000000
# 75%         1.0    43.000000    84.000000     78.000000    569.000000
# max         1.0    69.000000   100.000000    100.000000   4508.000000
#
#          insurance  median_school  num_schools
# count  1883.000000    1883.000000  1883.000000
# mean    140.454063       6.502921     2.793415
# std      72.929765       1.996109     0.505358
# min      30.000000       1.000000     1.000000
# 25%      94.000000       5.000000     3.000000
# 50%     125.000000       7.000000     3.000000
# ...

# %%
sns.countplot(y='exterior_walls', data=df)

# %%
for features in df.dtypes[df.dtypes == 'object'].index:
    sns.countplot(y=features, data=df)
    plt.show()

# %% [markdown]
# ### Segmentations
# Good to observe the relationship between categorical features and numeric features

# %%
sns.boxplot(y='property_type', x='tx_price', data=df)

# %% [markdown]
# ### Groupby

# %%
df.groupby('property_type').mean()
# Out:
#                                     tx_price      beds     baths         sqft  \
# property_type
# Apartment / Condo / Townhouse  366614.034869  2.601494  2.200498  1513.727273
# Single-Family                  464644.711111  4.029630  2.862037  2935.865741
#
#                                 year_built      lot_size  basement  \
# property_type
# Apartment / Condo / Townhouse  1988.936488   3944.239103       1.0
# Single-Family                  1978.523148  20417.666667       1.0
#
#                                restaurants  groceries  nightlife     cafes  \
# property_type
# Apartment / Condo / Townhouse    58.418431   5.919054   7.855542  8.037360
# Single-Family                    26.672222   3.453704   3.007407  3.308333
#
#                                 shopping  arts_entertainment  beauty_spas  \
# property_type
# Apartment / Condo / Townhouse  57.631382            4.840598    32.087173
# Single-Family                  28.289815            2.318519    16.970370
#
# ...

# %%
sns.boxplot(y='property_type', x='sqft', data=df)

# %%
# segment by property_type and display the means and standard deviations within each class
df.groupby('property_type').agg([np.mean, np.std])
# Out:
#                                     tx_price                     beds  \
#                                         mean            std      mean
# property_type
# Apartment / Condo / Townhouse  366614.034869  121784.490486  2.601494
# Single-Family                  464644.711111  157758.739013  4.029630
#
#                                             baths                   sqft  \
#                                     std      mean       std         mean
# property_type
# Apartment / Condo / Townhouse  0.810220  2.200498  0.815009  1513.727273
# Single-Family                  0.795639  2.862037  0.937551  2935.865741
#
#                                              year_built             \
#                                        std         mean        std
# property_type
# Apartment / Condo / Townhouse   556.286650  1988.936488  15.513640
# Single-Family                  1422.871169  1978.523148  22.210582
#
# ...

# %% [markdown]
# ### Correlations as Heatmap
# Relationships between numeric features and other numer features

# %%
correlations = df.corr()

# %%
plt.figure(figsize=(7,6))
sns.heatmap(correlations)

# %%
# plot it bigger
sns.set_style('white')
plt.figure(figsize=(10,8))
sns.heatmap(correlations)

# %%
plt.figure(figsize=(10,8))
# for dipaying percentage values
correlations = correlations * 100 
sns.heatmap(correlations, annot=True, fmt='.0f')

# %%
# create a mask with 23,23 dimensionality and trim them from the middle
mask = np.zeros_like(correlations, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlations, annot=True, fmt='.0f', mask=mask)
